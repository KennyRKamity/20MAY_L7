# %% [markdown]
# <a href="https://colab.research.google.com/github/KennyRKamity/20MAY_L7/blob/main/lab2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
x<- c("apple", "grapes", "jackfruit", "mango")
print(x[1:3])
# Out:
# [1] "apple"     "grapes"    "jackfruit"
